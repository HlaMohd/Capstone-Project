# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/SWaT.csv")

# %%
df.head()
# Out:
#                  Timestamp    FIT101    LIT101   MV101  P101  P102    AIT201  \
# 0   28/12/2015 10:00:00 AM  2.427057  522.8467     2.0     2     1  262.0161
# 1   28/12/2015 10:00:01 AM  2.446274  522.8860     2.0     2     1  262.0161
# 2   28/12/2015 10:00:02 AM  2.489191  522.8467     2.0     2     1  262.0161
# 3   28/12/2015 10:00:03 AM  2.534350  522.9645     2.0     2     1  262.0161
# 4   28/12/2015 10:00:04 AM  2.569260  523.4748     2.0     2     1  262.0161
#
#      AIT202    AIT203    FIT201  ...  P501  P502    PIT501    PIT502  \
# 0  8.396437  328.6337  2.445391  ...     2     1  250.8652  1.649953
# 1  8.396437  328.6337  2.445391  ...     2     1  250.8652  1.649953
# 2  8.394514  328.6337  2.442316  ...     2     1  250.8812  1.649953
# 3  8.394514  328.6337  2.442316  ...     2     1  250.8812  1.649953
# 4  8.394514  328.6337  2.443085  ...     2     1  250.8812  1.649953
#
#      PIT503    FIT601  P601  P602  P603  Normal/Attack
# ...

# %%
df.shape
# Out:
# (1441719, 53)

# %%
df.columns
# Out:
# Index([' Timestamp', 'FIT101', 'LIT101', ' MV101', 'P101', 'P102', ' AIT201',
#        'AIT202', 'AIT203', 'FIT201', ' MV201', ' P201', ' P202', 'P203',
#        ' P204', 'P205', 'P206', 'DPIT301', 'FIT301', 'LIT301', 'MV301',
#        'MV302', ' MV303', 'MV304', 'P301', 'P302', 'AIT401', 'AIT402',
#        'FIT401', 'LIT401', 'P401', 'P402', 'P403', 'P404', 'UV401', 'AIT501',
#        'AIT502', 'AIT503', 'AIT504', 'FIT501', 'FIT502', 'FIT503', 'FIT504',
#        'P501', 'P502', 'PIT501', 'PIT502', 'PIT503', 'FIT601', 'P601', 'P602',
#        'P603', 'Normal/Attack'],
#       dtype='str')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['Timestamp', 'FIT101', 'LIT101', 'MV101', 'P101', 'P102', 'AIT201',
#        'AIT202', 'AIT203', 'FIT201', 'MV201', 'P201', 'P202', 'P203', 'P204',
#        'P205', 'P206', 'DPIT301', 'FIT301', 'LIT301', 'MV301', 'MV302',
#        'MV303', 'MV304', 'P301', 'P302', 'AIT401', 'AIT402', 'FIT401',
#        'LIT401', 'P401', 'P402', 'P403', 'P404', 'UV401', 'AIT501', 'AIT502',
#        'AIT503', 'AIT504', 'FIT501', 'FIT502', 'FIT503', 'FIT504', 'P501',
#        'P502', 'PIT501', 'PIT502', 'PIT503', 'FIT601', 'P601', 'P602', 'P603',
#        'Normal/Attack'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1441719 entries, 0 to 1441718
# Data columns (total 53 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Timestamp      1441719 non-null  str
#  1   FIT101         1441719 non-null  float64
#  2   LIT101         1441719 non-null  float64
#  3   MV101          449919 non-null   float64
#  4   P101           1441719 non-null  int64
#  5   P102           1441719 non-null  int64
#  6   AIT201         449919 non-null   float64
#  7   AIT202         1441719 non-null  float64
#  8   AIT203         1441719 non-null  float64
#  9   FIT201         1441719 non-null  float64
#  10  MV201          449919 non-null   float64
#  11  P201           449919 non-null   float64
#  12  P202           449919 non-null   float64
#  13  P203           1441719 non-null  int64
#  14  P204           449919 non-null   float64
#  15  P205           1441719 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Timestam
0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(494991)

# %%
df[df.duplicated(keep=False)].head()
# Out:
#                      Timestamp  FIT101    LIT101  P101  P102    AIT202  \
# 397098   22/12/2015 4:30:00 PM     0.0  124.3135     1     1  8.313446
# 397099   22/12/2015 4:30:01 PM     0.0  124.3920     1     1  8.313446
# 397100   22/12/2015 4:30:02 PM     0.0  124.4705     1     1  8.313446
# 397101   22/12/2015 4:30:03 PM     0.0  124.6668     1     1  8.313446
# 397102   22/12/2015 4:30:04 PM     0.0  124.5098     1     1  8.313446
#
#           AIT203  FIT201  P203  P205  ...  P501  P502    PIT501  PIT502  \
# 397098  312.7916     0.0     1     1  ...     1     1  9.100231     0.0
# 397099  312.7916     0.0     1     1  ...     1     1  9.100231     0.0
# 397100  312.7916     0.0     1     1  ...     1     1  9.100231     0.0
# 397101  312.7916     0.0     1     1  ...     1     1  9.100231     0.0
# 397102  312.7916     0.0     1     1  ...     1     1  9.100231     0.0
#
#         PIT503    FIT601  P601  P602  P603  Normal/Attack
# ...

# %%
df[df.duplicated(keep=False)].shape
# Out:
# (989982, 46)

# %%
df["Timestamp"].duplicated().sum()
# Out:
# np.int64(494991)

# %%
df.drop(columns=["Timestamp"]).value_counts().head(10)
# Out:
# FIT101    LIT101    P101  P102  AIT202    AIT203    FIT201    P203  P205  P206  DPIT301    FIT301    LIT301     MV301  MV302  MV304  P301  P302  AIT401    AIT402    FIT401    LIT401    P401  P402  P403  P404  UV401  AIT501    AIT502    AIT503    AIT504    FIT501    FIT502    FIT503    FIT504    P501  P502  PIT501    PIT502    PIT503    FIT601    P601  P602  P603  Normal/Attack
# 2.424174  502.7101  2     1     8.356383  335.3243  2.450389  2     2     1     2.756258   0.385741  883.4274   1      1      2      1     1     148.8032  172.9813  1.697370  906.3830  1     2     1     1     2      7.872533  164.7526  265.1884  11.11254  1.706229  1.277956  0.742182  0.310540  2     1     255.2070  1.217441  193.8445  0.000256  1     1     1     Normal           6
# ...

# %%
df["Normal/Attack"].value_counts()
# Out:
# Normal/Attack
# Normal    1387098
# Attack      54621
# Name: count, dtype: int64

# %%
df['Normal/Attack'].unique()
# Out:
# <StringArray>
# ['Normal', 'Attack']
# Length: 2, dtype: str

# %%
df["Normal/Attack"] = df["Normal/Attack"].map({
    "Normal": 0,
    "Attack": 1
})

# %%
df["Normal/Attack"].value_counts()
# Out:
# Normal/Attack
# 0    1387098
# 1      54621
# Name: count, dtype: int64

# %%
df = df.drop("Normal/Attack1", axis=1)

# %%
X = df.drop(columns=["Normal/Attack", "Timestamp"])
y = df["Normal/Attack"]

# %%
missing = X.isnull().sum()
missing[missing > 0].sort_values(ascending=False)
# Out:
# Series([], dtype: int64)

# %%
missing_percentage = (X.isnull().mean() * 100).sort_values(ascending=False)
missing_percentage[missing_percentage > 0]
# Out:
# Series([], dtype: float64)

# %%
X.dtypes.value_counts()
# Out:
# float64    24
# int64      20
# Name: count, dtype: int64

# %%
X.duplicated().sum()
# Out:
# np.int64(512823)

# %%
y.value_counts()
# Out:
# Normal/Attack
# 0    1387098
# 1      54621
# Name: count, dtype: int64

# %%
y.value_counts(normalize=True)*100
# Out:
# Normal/Attack
# 0    96.211398
# 1     3.788602
# Name: proportion, dtype: float64

# %%
df.to_csv("../data/processed/SWaT_cleaned.csv", index=False)
